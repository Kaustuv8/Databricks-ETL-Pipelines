# %%
# %sql
CREATE SCHEMA IF NOT EXISTS BRONZE
  MANAGED LOCATION 'abfss://data@stdevwesteuropewrmp.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS SILVER
MANAGED LOCATION 'abfss://data@stdevwesteuropewrmp.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS GOLD
MANAGED LOCATION 'abfss://data@stdevwesteuropewrmp.dfs.core.windows.net/gold';
